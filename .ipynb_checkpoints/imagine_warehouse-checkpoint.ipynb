# %%
# warehouse_nodeを読んで、使わないノードを経由したルートを作る(start_node,end_node,最短距離,最短距離の経由方法)
# 全点よりダイクストラをして、他の点への最短ルートと最短距離を記録

from heapq import*
import pandas as pd

def DIJKSTRA(point,d):
    cost      = [float("inf")]*n
    path      = [[]for i in range(n)]
    Q         = []
    cost[point]=0
    path[point]=[point]
    heappush(Q,(point,cost[point],path[point]))
    while Q:
        prefnd,tmpC,tmpP=heappop(Q)
        if cost[prefnd]<tmpC:
            continue
        for node,c in d[prefnd]:
            altC=c+tmpC
            altP=tmpP+[node]
            if cost[node]>altC:
                path[node]=altP
                cost[node]=altC
                heappush(Q,(node,altC,altP))
    return cost,path

dfnode=pd.read_excel("./warehouse_node.xlsx").fillna("")

n=max(dfnode["node_number"])+1
d=[[]for i in range(n)]

nodelist=pd.concat([dfnode.loc[:,"node_number"],dfnode.loc[:,"connect_node_1":"connect_node_4"]],axis=1).values.tolist()

d={ line[0]:[int(num) for num in line[1:] if type(num)!=str] for line in nodelist}
d={k:[(i,1)for i in v] for k,v in d.items()}

toexcel=[["start","end","cost","root"]]
for start in range(n):
    c,p=DIJKSTRA(start,d)
    for end,cost,path in zip(range(n),c,p):
        toexcel.append([start,end,cost,",".join(map(str,path))])

pd.DataFrame(toexcel).to_excel("./warehouse_root.xlsx",header=None,index=None)

# %%
# 仮想ピッキングクエリー作成

import random as rd

inventry=[chr(i+65) for i in range(26)]+[chr(i+97) for i in range(6)]

l=[]
for i in range(100):
    num=random.randint(1,10)

    l.append("start,"+",".join( sorted(set(inventry[rd.randint(0,len(inventry)-1)]for i in range(num))) ))

pd.DataFrame(l).to_excel("query.xlsx",header=None,index=None)

# %%
import sys
sys.path.append('./')

import TSP
import math
import random
import pandas as pd

dfnode=pd.read_excel("warehouse_node.xlsx")
dfroot=pd.read_excel("warehouse_root.xlsx").values.tolist()
dfwii ={name:node for name,node in pd.read_excel("where_is_inventry.xlsx").values.tolist()}
query =pd.read_excel("query.xlsx",header=None).values.tolist()

for q in query:
    print(q[0])
    q=set([dfwii[name]for name in q[0].split(",")])
    n=len(q)
    oldtonew={node:newnode for newnode,node in enumerate(q)}
    newtoold={newnode:node for node,newnode in oldtonew.items()}
    dist = {(oldtonew[start],oldtonew[end]):cost for start,end,cost,root in dfroot if start>end and start in q and end in q}
#    print(dist)
    try:
        root,cost=TSP.main(n,dist)
        root=[newtoold[i]for i in root]
        print(root,cost)
    except:
        print("error something wrong")

#print(points)
#print(dist)
# Out:
# start,A,H,M,W,X,b,c
# [5, 9, 24, 23, 27, 12, 15] 24.0
# start,E,G,K,P,T,V,X
# [7, 8, 23, 24, 14, 11, 15, 22] 24.0
# start,G,P,U,Y,b
# [8, 14, 22, 27, 25, 15] 20.0
# start,I,P
# [10, 14, 15] 12.0
# start,M
# error something wrong
# start,X,f
# [24, 15, 29] 12.0
# start,G,H,J,O,Z,d
# [8, 9, 15, 11, 26, 28, 13] 22.0
# start,B,J,K,N,V,c,e
# [6, 11, 15, 27, 28, 23, 13] 18.0
# start,F,J,L,N,b
# [8, 11, 15, 27, 12, 13] 18.0
# start,I,R,d
# [10, 15, 28, 21] 14.0
# start,A,E,Z,a
# [26, 7, 5, 15] 14.0
# start,F
# error something wrong
# start,E,F,P,d
# [7, 8, 14, 28, 15] 20.0
# start,A,E,O,P,S,U
# [5, 7, 22, 14, 13, 21, 15] 22.0
# start,B,G,I,K,N,U,Z,b,d
# [6, 8, 13, 28, 26, 27, 22, 15, 10, 11] 24.0
# start,B,E,S,U,W,Z,d,e
# [6, 7, 22, 23, 28, 26, 21, 15] 20.0
# start,C,D,E,M,P,R,W,d,f
# [6, 7, 12, 14, 29, 28, 23, 21, 15] 24.0
# start,D,Q,a,c
# [7, 15, 20, 26, 27] 16.0
# start,B,C,N,U,X,c,d
# [6, 15, 22, 27, 28, 13, 24] 22.0
# start,A,B,H,K,W,Y,b,f
# [5, 6, 11, 23, 9, 29, 27, 25, 15] 28.0
# start,A,D,G,Z,a
# [5, 8, 7, 26, 15] 18.0
# start,M,T,b,c
# [27, 15, 12, 22] 10.0
# start,D,H,L,Q
# [7, 9, 20, 15, 12] 16.0
# start,D,E,G,I,Q
# [7, 8, 15, 10, 20] 16.0
# start,D,V
# [7, 15, 23] 12.0
# start,C,I,R,a,b,d
# [6, 15, 10, 21, 26, 27, 28] 20.0
# start,A,D,H,e
# [5, 7, 9, 28, 15] 20.0
# start,C,E,L,M,N,U,W,a
# [6, 7, 12, 23, 13, 22, 15, 26] 22.0
# start,A,B,C,D,P,W,X,a
# [5, 6, 7, 23, 14, 24, 26, 15] 26.0
# start,A,K,M,R,d
# [5, 11, 21, 28, 12, 15] 20.0
# start,f
# error something wrong
# start,F,G,N,Q,a,b,e
# [8, 13, 28, 27, 26, 20, 15] 20.0
# start,A,M,N,Z,b
# [5, 15, 12, 13, 27, 26] 20.0
# start,A,F,L,P,Q,b,c,e
# [5, 8, 14, 28, 27, 12, 15, 20] 26.0
# start,C,L,Q,Y,e
# [6, 12, 28, 25, 20, 15] 18.0
# start,H,N,P,R,X,a,c
# [9, 14, 24, 13, 27, 26, 21, 15] 22.0
# start,I,L,N,R,Y,Z,c,f
# [10, 15, 21, 12, 13, 29, 27, 26, 25] 26.0
# start,G,H,J,K,N,S,Z,f
# [8, 9, 29, 26, 21, 15, 11, 13] 22.0
# start,D,F,H,S,T,U,W,X,e
# [7, 8, 9, 24, 23, 28, 22, 15, 21] 26.0
# start,B,J,S,V,X,Y
# [6, 11, 25, 15, 24, 23, 21] 22.0
# start,M,X,c,f
# [12, 15, 27, 29, 24] 16.0
# start,B,D,E,G,P,U,V,Y
# [6, 7, 8, 14, 23, 22, 25, 15] 26.0
# start,H,M,O,P,S,U,X,a
# [9, 14, 13, 12, 22, 15, 21, 26, 24] 24.0
# start,B,J,a
# [26, 11, 6, 15] 10.0
# start,E,F,H,K,N,W,X,Z,d,e
# [7, 9, 8, 13, 24, 23, 28, 26, 11, 15] 28.0
# start,K,S,W,Y,Z,c,e
# [11, 21, 15, 25, 26, 27, 28, 23] 20.0
# start,C,G,I,R,U,Z,d
# [6, 8, 28, 22, 15, 10, 26, 21] 24.0
# start,B,M,P,Z,a,b,d,e
# [6, 12, 14, 28, 27, 26, 15] 24.0
# start,J,b,c
# [27, 11, 15] 10.0
# start,E,L,R,Y,a
# [7, 12, 15, 25, 26, 21] 14.0
# start,X
# error something wrong
# start,H,T,U,b,c,f
# [9, 15, 22, 27, 29] 18.0
# start,M,c
# [27, 12, 15] 10.0
# start,I,J,N,S,W,Z
# [10, 11, 23, 13, 21, 26, 15] 18.0
# start,E,J,M,N,T,a
# [7, 12, 22, 13, 26, 11, 15] 20.0
# start,D,G,H,P,T,V,X,a
# [7, 8, 9, 14, 24, 23, 26, 15, 22] 26.0
# start,E,K,N,O,P,d
# [7, 11, 15, 28, 13, 14] 22.0
# start,K,Q,R,V,Z,e
# [11, 20, 15, 21, 26, 28, 23] 16.0
# start,A,D,I,U,Y,Z,d
# [5, 7, 22, 28, 26, 25, 15, 10] 22.0
# start,E,G,K,N,S,V,Y,b,d
# [7, 8, 13, 23, 28, 27, 25, 15, 11, 21] 24.0
# start,d
# error something wrong
# start,A,F,J,P
# [5, 8, 14, 11, 15] 18.0
# start,C,I,L,M,S,W,Z,e
# [6, 12, 23, 28, 26, 21, 10, 15] 20.0
# start,D,G,O,Q,R,Y,Z
# [7, 8, 13, 15, 20, 25, 26, 21] 18.0
# start,A,B,I,J,N,d,f
# [5, 6, 11, 28, 29, 13, 15, 10] 22.0
# start,A,B,C,F,M,V,d
# [5, 6, 8, 28, 23, 12, 15] 20.0
# start,J,L
# [11, 12, 15] 8.0
# start,C,G,H,I,J,c
# [6, 8, 9, 27, 10, 15, 11] 22.0
# start,H,I,K,M,S
# [9, 10, 15, 21, 11, 12] 20.0
# start,A,I,O,Y,d
# [5, 10, 25, 28, 13, 15] 18.0
# start,A,C,M
# [12, 6, 5, 15] 12.0
# start,A,B,C,F,G,Z
# [5, 8, 6, 26, 15] 18.0
# start,E,F,G,P,U,a,d
# [7, 8, 14, 28, 26, 15, 22] 24.0
# start,F,M,O,W,c,e
# [8, 13, 12, 15, 27, 28, 23] 18.0
# start,M,V,W,c,f
# [12, 15, 23, 29, 27] 18.0
# start,A,B,L,M
# [12, 6, 5, 15] 12.0
# start,G,P
# [8, 14, 15] 14.0
# start,D,E,J,N,V,f
# [7, 15, 11, 13, 29, 23] 22.0
# start,I,K,O,Y,Z,a
# [10, 15, 11, 13, 26, 25] 18.0
# start,B,C,D,M,S,Y,Z
# [6, 7, 12, 15, 25, 26, 21] 16.0
# start,I,L,M,O,Z,a
# [10, 15, 13, 12, 26] 16.0
# start,C,H,I,Q,R,U,X,d,f
# [6, 9, 24, 29, 28, 22, 10, 20, 15, 21] 28.0
# start,A,H,I,K,O,Y,a
# [5, 9, 13, 11, 26, 25, 15, 10] 24.0
# start,P,b,d
# [27, 15, 14, 28] 16.0
# start,B,X
# [24, 6, 15] 14.0
# start,D,b,f
# [27, 7, 15, 29] 18.0
# start,I,J,L,M,U,V,a,b
# [10, 15, 11, 12, 23, 22, 27, 26] 20.0
# start,C,G,O
# [8, 6, 15, 13] 12.0
# start,S,T,U,W,b
# [15, 21, 22, 27, 23] 14.0
# start,B,O,X,Y
# [6, 13, 24, 15, 25] 20.0
# start,A,D,H,R,S
# [5, 7, 9, 21, 15] 18.0
# start,E,F,K,L,M,N,T,W,e
# [7, 8, 13, 28, 23, 15, 11, 22, 12] 20.0
# start,H,I,K,N,U,X,Z
# [9, 10, 15, 11, 26, 22, 13, 24] 26.0
# start,J
# error something wrong
# start,C,I,M,P,Q
# [6, 10, 15, 20, 12, 14] 20.0
# start,A,O,T,V
# [5, 15, 23, 13, 22] 16.0
# start,F,I,L,O,R,U,V,Y,c
# [8, 13, 12, 22, 27, 25, 10, 15, 21, 23] 24.0
# start,F,J,Q,X,a,c
# [8, 24, 11, 20, 15, 26, 27] 24.0
# start,F,G,H,V,W,Y,Z,d
# [8, 9, 23, 28, 26, 25, 15] 22.0
# start,G,O,U,Y
# [8, 13, 15, 25, 22] 16.0
